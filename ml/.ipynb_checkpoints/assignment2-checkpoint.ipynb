# %% [markdown]
# ### ASSIGNMENT 2: PREDICT BOSTON HOUSING VALUES USING MLR

# %%
import pandas as pd

# %% [markdown]
#  ### PART 1: FIND OUT WHICH VARIABLES MAKE A BUSINESS SENSE TO KEEP
#  HEALTH OF DATA - missing values, outliers
#  DISTRIBUTION OF DATA - should be normal
#  LOOK AT SCATTER PLOTS/CORR OF ALL VARIABLES - shows absence of linear corr..if scatter is curving around
#  it gives hint on what kind of model/transformations to apply
#  Above will give idea of what variables to keep, what transformations to apply
#
#  Lets take Motor Score as dependent variable. Total Score could also be..
#  Others are independent variables/predictors/features

# %%
boston_housing_df = pd.read_csv("boston.csv")
boston_housing_df.head()
# Out:
#       CRIM  INDUS    NOX     RM        AGE     DIS  TAX         PT  \
# 0  0.00632   2.31  0.538  6.575  65.199997  4.0900  296  15.300000
# 1  0.02731   7.07  0.469  6.421  78.900002  4.9671  242  17.799999
# 2  0.02729   7.07  0.469  7.185  61.099998  4.9671  242  17.799999
# 3  0.03237   2.18  0.458  6.998  45.799999  6.0622  222  18.700001
# 4  0.06905   2.18  0.458  7.147  54.200001  6.0622  222  18.700001
#
#             B         MV
# 0  396.899994  24.000000
# 1  396.899994  21.600000
# 2  392.829987  34.700001
# 3  394.630005  33.400002
# 4  396.899994  36.200001

# %%
boston_housing_df.dtypes
# Out:
# CRIM     float64
# INDUS    float64
# NOX      float64
# RM       float64
# AGE      float64
# DIS      float64
# TAX        int64
# PT       float64
# B        float64
# MV       float64
# dtype: object

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.136779    0.554695    6.284634   68.574901    3.795043
# std      8.601545    6.860353    0.115878    0.702617   28.148862    2.105710
# min      0.006320    0.460000    0.385000    3.561000    2.900000    1.129600
# 25%      0.082045    5.190000    0.449000    5.885500   45.025000    2.100175
# 50%      0.256510    9.690000    0.538000    6.208500   77.500000    3.207450
# 75%      3.677083   18.100000    0.624000    6.623500   94.074999    5.188425
# max     88.976196   27.740000    0.871000    8.780000  100.000000   12.126500
#
#               TAX          PT           B          MV
# count  506.000000  506.000000  506.000000  506.000000
# mean   408.237154   18.455534  356.674030   22.532806
# std    168.537116    2.164946   91.294863    9.197104
# min    187.000000   12.600000    0.320000    5.000000
# 25%    279.000000   17.400000  375.377487   17.025000
# 50%    330.000000   19.050000  391.440002   21.200001
# 75%    666.000000   20.200001  396.225006   25.000000
# max    711.000000   22.000000  396.899994   50.000000

# %%
from scipy import stats

# %%
import numpy as np 
boston_housing_df = boston_housing_df[(np.abs(stats.zscore(boston_housing_df))<3).all(axis=1)]

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  463.000000  463.000000  463.000000  463.000000  463.000000  463.000000
# mean     2.358735   10.772981    0.547157    6.297281   67.220950    3.870550
# std      4.720433    6.820539    0.114481    0.644675   28.236259    1.995765
# min      0.006320    0.460000    0.385000    4.368000    2.900000    1.129600
# 25%      0.076890    5.130000    0.448000    5.888500   42.500000    2.197700
# 50%      0.214090    8.560000    0.524000    6.211000   74.300003    3.414500
# 75%      1.921980   18.100000    0.611500    6.618500   93.599998    5.287300
# max     28.655800   27.740000    0.871000    8.375000  100.000000    9.222900
#
#               TAX          PT           B          MV
# count  463.000000  463.000000  463.000000  463.000000
# mean   390.989201   18.336501  374.761855   23.115119
# std    160.054232    2.163748   51.034829    8.811093
# min    188.000000   12.600000   83.449997    5.600000
# 25%    277.000000   16.900000  378.169998   17.799999
# 50%    311.000000   18.700001  392.519989   21.700001
# 75%    437.000000   20.200001  396.899994   25.750000
# max    711.000000   21.200001  396.899994   50.000000

# %%
boston_housing_df['log_CRIM'] = np.log10(boston_housing_df['CRIM'])
boston_housing_df = boston_housing_df.drop(columns = ['CRIM'])
boston_housing_df['log_DIS'] = np.log10(boston_housing_df['DIS'])
boston_housing_df = boston_housing_df.drop(columns = ['DIS'])

# %%
import seaborn as sns

# %%
sns.pairplot(boston_housing_df)

# %%
sns.heatmap(boston_housing_df.isnull(), cbar=False)

# %%
sns.set(color_codes=True)

# %%
sns.set(style='white', palette='muted')

# %%
sns.distplot(boston_housing_df['MV'])

# CRIM, DIS, B - take logs..
# Out:
# C:\Users\vijay.agrawal\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import numpy as np
np.histogram(boston_housing_df['MV'], bins=10)
# Out:
# (array([ 11,  48,  81, 154,  67,  39,  28,   7,  10,  18], dtype=int64),
#  array([ 5.5999999 , 10.03999991, 14.47999992, 18.91999993, 23.35999994,
#         27.79999995, 32.23999996, 36.67999997, 41.11999998, 45.55999999,
#         50.        ]))

# %%
corr = np.round(boston_housing_df.corr(), decimals=2)

# %%
corr.style.background_gradient(cmap='seismic')
# Out:
# <style  type="text/css" >
#     #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col0 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col1 {
#             background-color:  #c30000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col2 {
#             background-color:  #00004c;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col3 {
#             background-color:  #ea0000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col4 {
#             background-color:  #e00000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col5 {
#             background-color:  #ffc5c5;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col6 {
#             background-color:  #00006b;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col7 {
#             background-color:  #000055;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col8 {
#             background-color:  #d60000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow0_col9 {
#             background-color:  #00006b;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col0 {
#             background-color:  #c80000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col1 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col2 {
#             background-color:  #00006e;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col3 {
#             background-color:  #d00000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col4 {
#             background-color:  #f20000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col5 {
#             background-color:  #b5b5ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col6 {
#             background-color:  #00004f;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col7 {
#             background-color:  #00006e;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col8 {
#             background-color:  #c00000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow1_col9 {
#             background-color:  #00004c;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col0 {
#             background-color:  #0000d6;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col1 {
#             background-color:  #1111ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col2 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col3 {
#             background-color:  #2121ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col4 {
#             background-color:  #0000d6;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col5 {
#             background-color:  #00008a;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col6 {
#             background-color:  #8989ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col7 {
#             background-color:  #d60000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col8 {
#             background-color:  #0000f7;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow2_col9 {
#             background-color:  #ff9999;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col0 {
#             background-color:  #ec0000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col1 {
#             background-color:  #ce0000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col2 {
#             background-color:  #000098;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col3 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col4 {
#             background-color:  #ff4d4d;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col5 {
#             background-color:  #f5f5ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col6 {
#             background-color:  #000092;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col7 {
#             background-color:  #00007c;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col8 {
#             background-color:  #ea0000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow3_col9 {
#             background-color:  #000066;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col0 {
#             background-color:  #d60000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col1 {
#             background-color:  #e30000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col2 {
#             background-color:  #00008d;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col3 {
#             background-color:  #ff2d2d;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col4 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col5 {
#             background-color:  #ff9595;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col6 {
#             background-color:  #000074;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col7 {
#             background-color:  #00006e;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col8 {
#             background-color:  #ba0000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow4_col9 {
#             background-color:  #0000a9;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col0 {
#             background-color:  #ff7d7d;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col1 {
#             background-color:  #ffd5d5;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col2 {
#             background-color:  #00006e;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col3 {
#             background-color:  #ffb5b5;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col4 {
#             background-color:  #ff7575;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col5 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col6 {
#             background-color:  #0909ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col7 {
#             background-color:  #00004c;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col8 {
#             background-color:  #ff8181;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow5_col9 {
#             background-color:  #5555ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col0 {
#             background-color:  #0000fa;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col1 {
#             background-color:  #0101ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col2 {
#             background-color:  #9595ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col3 {
#             background-color:  #2d2dff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col4 {
#             background-color:  #0000cd;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col5 {
#             background-color:  #3939ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col6 {
#             background-color:  #800000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col7 {
#             background-color:  #e5e5ff;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col8 {
#             background-color:  #0000d8;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow6_col9 {
#             background-color:  #ff8d8d;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col0 {
#             background-color:  #0000c5;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col1 {
#             background-color:  #0000f4;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col2 {
#             background-color:  #da0000;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col3 {
#             background-color:  #0000e9;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col4 {
#             background-color:  #0000a0;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col5 {
#             background-color:  #00004c;
#         }    #T_b1d880ca_6472_11e9_8a0e_b00cd128693brow7_col6 {
#             bac

# %%
corr.to_csv('corr2.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-282-7583aaf2c9d4> in <module>
# ----> 1 corr.to_csv('corr2.csv')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'corr2.csv'

# %%
corr.to_csv('corr3.csv')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(boston_housing_df.drop("MV", axis=1), boston_housing_df['MV'], test_size = 0.2, random_state = 112)

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)

# %%
my_model = sm.OLS(Y_train, X_train)

# %%
result=my_model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     86.87
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           1.09e-84
# Time:                        01:50:10   Log-Likelihood:                -1113.3
# No. Observations:                 370   AIC:                             2247.
# Df Residuals:                     360   BIC:                             2286.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.0396      6.578      2.134      0.033       1.103      26.976
# INDUS         -0.0545      0.072     -0.759      0.449      -0.196       0.087
# NOX          -22.3426      4.968     -4.497      0.000     -32.113     -12.573
# RM             7.9994      0.462     17.301      0.000       7.090       8.909
# AGE           -0.0760      0.015     -5.104      0.000      -0.105      -0.047
# TAX           -0.0068      0.003     -2.307      0.022      -0.013      -0.001
# PT            -0.9168      0.146     -6.270      0.000      -1.204      -0.629
# B              0.0142      0.005      2.632      0.009       0.004       0.025
# log_CRIM       1.1260      0.619      1.818      0.070      -0.092       2.344
# log_DIS      -16.2952      2.372     -6.869      0.000     -20.961     -11.630
# ==============================================================================
# Omnibus:                      222.678   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3496.379
# Skew:                           2.202   Prob(JB):                         0.00
# Kurtosis:                      17.402   Cond. No.                     1.66e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(boston_housing_df.drop("MV", axis=1), boston_housing_df['MV'], test_size = 0.2, random_state = 112)

# %%
X_train = sm.add_constant(X_train)

# %%
my_model = sm.OLS(Y_train, X_train)

# %%
result=my_model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     86.87
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           1.09e-84
# Time:                        01:52:33   Log-Likelihood:                -1113.3
# No. Observations:                 370   AIC:                             2247.
# Df Residuals:                     360   BIC:                             2286.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.0396      6.578      2.134      0.033       1.103      26.976
# INDUS         -0.0545      0.072     -0.759      0.449      -0.196       0.087
# NOX          -22.3426      4.968     -4.497      0.000     -32.113     -12.573
# RM             7.9994      0.462     17.301      0.000       7.090       8.909
# AGE           -0.0760      0.015     -5.104      0.000      -0.105      -0.047
# TAX           -0.0068      0.003     -2.307      0.022      -0.013      -0.001
# PT            -0.9168      0.146     -6.270      0.000      -1.204      -0.629
# B              0.0142      0.005      2.632      0.009       0.004       0.025
# log_CRIM       1.1260      0.619      1.818      0.070      -0.092       2.344
# log_DIS      -16.2952      2.372     -6.869      0.000     -20.961     -11.630
# ==============================================================================
# Omnibus:                      222.678   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3496.379
# Skew:                           2.202   Prob(JB):                         0.00
# Kurtosis:                      17.402   Cond. No.                     1.66e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
#  Observe the P values in the results for each variable.
#  In previous steps, we found HNR, Jitter(%) to be highly correlated with others. Remove them
#  Also any variable with p-value > 0.05, remove it

# %%
X_train.drop([INDUS'], axis=1, inplace = True)
# Out:
#   File "<ipython-input-295-8cce2d70370c>", line 1
#     X_train.drop([INDUS'], axis=1, inplace = True)
#                                                   ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
#  Observe the P values in the results for each variable.
#  In previous steps, we found HNR, Jitter(%) to be highly correlated with others. Remove them
#  Also any variable with p-value > 0.05, remove it

# %%
X_train.drop(['INDUS'], axis=1, inplace = True)

# %%
my_model2 = sm.OLS(Y_train, X_train)

# %%
result2 = my_model2.fit()

# %%
print (result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     97.78
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           1.42e-85
# Time:                        01:53:02   Log-Likelihood:                -1113.6
# No. Observations:                 370   AIC:                             2245.
# Df Residuals:                     361   BIC:                             2280.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.5596      6.544      2.072      0.039       0.691      26.429
# NOX          -23.0552      4.876     -4.729      0.000     -32.643     -13.467
# RM             8.0734      0.452     17.873      0.000       7.185       8.962
# AGE           -0.0769      0.015     -5.185      0.000      -0.106      -0.048
# TAX           -0.0075      0.003     -2.705      0.007      -0.013      -0.002
# PT            -0.9272      0.145     -6.373      0.000      -1.213      -0.641
# B              0.0145      0.005      2.691      0.007       0.004       0.025
# log_CRIM       1.1477      0.618      1.856      0.064      -0.068       2.364
# log_DIS      -15.7973      2.279     -6.933      0.000     -20.278     -11.317
# ==============================================================================
# Omnibus:                      225.230   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3593.845
# Skew:                           2.231   Prob(JB):                         0.00
# Kurtosis:                      17.601   Cond. No.                     1.66e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
boston_housing_df = pd.read_csv("boston.csv")
boston_housing_df.head()
# Out:
#       CRIM  INDUS    NOX     RM        AGE     DIS  TAX         PT  \
# 0  0.00632   2.31  0.538  6.575  65.199997  4.0900  296  15.300000
# 1  0.02731   7.07  0.469  6.421  78.900002  4.9671  242  17.799999
# 2  0.02729   7.07  0.469  7.185  61.099998  4.9671  242  17.799999
# 3  0.03237   2.18  0.458  6.998  45.799999  6.0622  222  18.700001
# 4  0.06905   2.18  0.458  7.147  54.200001  6.0622  222  18.700001
#
#             B         MV
# 0  396.899994  24.000000
# 1  396.899994  21.600000
# 2  392.829987  34.700001
# 3  394.630005  33.400002
# 4  396.899994  36.200001

# %%
boston_housing_df.dtypes
# Out:
# CRIM     float64
# INDUS    float64
# NOX      float64
# RM       float64
# AGE      float64
# DIS      float64
# TAX        int64
# PT       float64
# B        float64
# MV       float64
# dtype: object

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.136779    0.554695    6.284634   68.574901    3.795043
# std      8.601545    6.860353    0.115878    0.702617   28.148862    2.105710
# min      0.006320    0.460000    0.385000    3.561000    2.900000    1.129600
# 25%      0.082045    5.190000    0.449000    5.885500   45.025000    2.100175
# 50%      0.256510    9.690000    0.538000    6.208500   77.500000    3.207450
# 75%      3.677083   18.100000    0.624000    6.623500   94.074999    5.188425
# max     88.976196   27.740000    0.871000    8.780000  100.000000   12.126500
#
#               TAX          PT           B          MV
# count  506.000000  506.000000  506.000000  506.000000
# mean   408.237154   18.455534  356.674030   22.532806
# std    168.537116    2.164946   91.294863    9.197104
# min    187.000000   12.600000    0.320000    5.000000
# 25%    279.000000   17.400000  375.377487   17.025000
# 50%    330.000000   19.050000  391.440002   21.200001
# 75%    666.000000   20.200001  396.225006   25.000000
# max    711.000000   22.000000  396.899994   50.000000

# %%
from scipy import stats

# %%
import numpy as np 
boston_housing_df = boston_housing_df[(np.abs(stats.zscore(boston_housing_df))<3).all(axis=1)]

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  463.000000  463.000000  463.000000  463.000000  463.000000  463.000000
# mean     2.358735   10.772981    0.547157    6.297281   67.220950    3.870550
# std      4.720433    6.820539    0.114481    0.644675   28.236259    1.995765
# min      0.006320    0.460000    0.385000    4.368000    2.900000    1.129600
# 25%      0.076890    5.130000    0.448000    5.888500   42.500000    2.197700
# 50%      0.214090    8.560000    0.524000    6.211000   74.300003    3.414500
# 75%      1.921980   18.100000    0.611500    6.618500   93.599998    5.287300
# max     28.655800   27.740000    0.871000    8.375000  100.000000    9.222900
#
#               TAX          PT           B          MV
# count  463.000000  463.000000  463.000000  463.000000
# mean   390.989201   18.336501  374.761855   23.115119
# std    160.054232    2.163748   51.034829    8.811093
# min    188.000000   12.600000   83.449997    5.600000
# 25%    277.000000   16.900000  378.169998   17.799999
# 50%    311.000000   18.700001  392.519989   21.700001
# 75%    437.000000   20.200001  396.899994   25.750000
# max    711.000000   21.200001  396.899994   50.000000

# %%
corr = np.round(boston_housing_df.corr(), decimals=2)

# %%
corr.style.background_gradient(cmap='seismic')
# Out:
# <style  type="text/css" >
#     #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col0 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col1 {
#             background-color:  #ff2d2d;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col2 {
#             background-color:  #ff0d0d;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col3 {
#             background-color:  #000098;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col4 {
#             background-color:  #ff5555;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col5 {
#             background-color:  #0000c8;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col6 {
#             background-color:  #da0000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col7 {
#             background-color:  #ffc9c9;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col8 {
#             background-color:  #000071;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow0_col9 {
#             background-color:  #000076;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col0 {
#             background-color:  #ff5d5d;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col1 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col2 {
#             background-color:  #c80000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col3 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col4 {
#             background-color:  #ec0000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col5 {
#             background-color:  #000068;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col6 {
#             background-color:  #e30000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col7 {
#             background-color:  #ffc5c5;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col8 {
#             background-color:  #000066;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow1_col9 {
#             background-color:  #000055;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col0 {
#             background-color:  #ff4949;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col1 {
#             background-color:  #ca0000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col2 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col3 {
#             background-color:  #00006e;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col4 {
#             background-color:  #d20000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col5 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col6 {
#             background-color:  #f80000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col7 {
#             background-color:  #b5b5ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col8 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow2_col9 {
#             background-color:  #00006e;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col0 {
#             background-color:  #0000ae;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col1 {
#             background-color:  #0000c5;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col2 {
#             background-color:  #0000fa;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col3 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col4 {
#             background-color:  #1919ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col5 {
#             background-color:  #ffbdbd;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col6 {
#             background-color:  #0000bc;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col7 {
#             background-color:  #00008a;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col8 {
#             background-color:  #8585ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow3_col9 {
#             background-color:  #d60000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col0 {
#             background-color:  #ff9595;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col1 {
#             background-color:  #ee0000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col2 {
#             background-color:  #d00000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col3 {
#             background-color:  #000098;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col4 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col5 {
#             background-color:  #000058;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col6 {
#             background-color:  #ff5d5d;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col7 {
#             background-color:  #f5f5ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col8 {
#             background-color:  #000090;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow4_col9 {
#             background-color:  #00007c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col0 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col1 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col2 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col3 {
#             background-color:  #d1d1ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col4 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col5 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col6 {
#             background-color:  #00004c;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col7 {
#             background-color:  #0000bf;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col8 {
#             background-color:  #cdcdff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow5_col9 {
#             background-color:  #e5e5ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col0 {
#             background-color:  #de0000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col1 {
#             background-color:  #da0000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col2 {
#             background-color:  #e80000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col3 {
#             background-color:  #00008d;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col4 {
#             background-color:  #ff3131;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col5 {
#             background-color:  #0000b1;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col6 {
#             background-color:  #800000;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col7 {
#             background-color:  #ff9595;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col8 {
#             background-color:  #000071;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow6_col9 {
#             background-color:  #00006e;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col0 {
#             background-color:  #ffcdcd;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col1 {
#             background-color:  #ff8585;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col2 {
#             background-color:  #ffe5e5;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col3 {
#             background-color:  #00006e;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col4 {
#             background-color:  #ffb9b9;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col5 {
#             background-color:  #3939ff;
#         }    #T_6f29af5e_6473_11e9_9697_b00cd128693brow7_col6 {
#             bac

# %% [markdown]
#  Watch for corr coefficients..Value > 0.6 generally means high correlation <br/>
#  High value means there is linear correlation, but low value does not mean there is no correlation
#  As can be seen in output, for motor_UPDRS, only age has a slight correlation, all other fields
#  are weak.
#  Also look at corr coefficients between the independent variables
#  Shimmer variable is highly correlated with Shimmer(db), Shimmer APQ3 etc..remove ones that are not
#  relevant from business standpoint

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(boston_housing_df.drop("MV", axis=1), boston_housing_df['MV'], test_size = 0.2, random_state = 112)

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)

# %%
my_model = sm.OLS(Y_train, X_train)

# %%
result=my_model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.665
# Method:                 Least Squares   F-statistic:                     82.42
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           6.37e-82
# Time:                        01:54:40   Log-Likelihood:                -1119.9
# No. Observations:                 370   AIC:                             2260.
# Df Residuals:                     360   BIC:                             2299.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.7563      6.327      0.910      0.364      -6.687      18.199
# CRIM          -0.1412      0.081     -1.750      0.081      -0.300       0.017
# INDUS         -0.0537      0.074     -0.726      0.468      -0.199       0.092
# NOX          -15.3156      4.696     -3.261      0.001     -24.551      -6.080
# RM             7.7911      0.475     16.397      0.000       6.857       8.725
# AGE           -0.0631      0.015     -4.238      0.000      -0.092      -0.034
# DIS           -1.4443      0.235     -6.152      0.000      -1.906      -0.983
# TAX            0.0009      0.003      0.302      0.763      -0.005       0.007
# PT            -0.9374      0.149     -6.298      0.000      -1.230      -0.645
# B              0.0116      0.005      2.119      0.035       0.001       0.022
# ==============================================================================
# Omnibus:                      261.295   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4588.494
# Skew:                           2.727   Prob(JB):                         0.00
# Kurtosis:                      19.367   Cond. No.                     1.52e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
#  Observe the P values in the results for each variable.
#  In previous steps, we found HNR, Jitter(%) to be highly correlated with others. Remove them
#  Also any variable with p-value > 0.05, remove it

# %%
X_train.drop(['INDUS', 'CRIM', 'TAX'], axis=1, inplace = True)

# %%
my_model2 = sm.OLS(Y_train, X_train)

# %%
result2 = my_model2.fit()

# %%
print (result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     122.5
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           4.47e-84
# Time:                        01:55:30   Log-Likelihood:                -1122.1
# No. Observations:                 370   AIC:                             2258.
# Df Residuals:                     363   BIC:                             2286.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.6450      6.206      1.071      0.285      -5.560      18.850
# NOX          -18.0833      4.124     -4.385      0.000     -26.194      -9.973
# RM             7.9052      0.461     17.130      0.000       6.998       8.813
# AGE           -0.0643      0.015     -4.341      0.000      -0.093      -0.035
# DIS           -1.3786      0.227     -6.084      0.000      -1.824      -0.933
# PT            -1.0214      0.135     -7.539      0.000      -1.288      -0.755
# B              0.0135      0.005      2.509      0.013       0.003       0.024
# ==============================================================================
# Omnibus:                      251.961   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4426.765
# Skew:                           2.584   Prob(JB):                         0.00
# Kurtosis:                      19.138   Cond. No.                     1.00e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_test = X_test.drop(['CRIM', 'INDUS', 'TAX'], axis=1)

# %%
predictions = result2.predict(sm.add_constant(X_test))

# %%
r2_score(Y_test, predictions)
# Out:
# 0.7086537676685092

# %%
boston_housing_df = pd.read_csv("boston.csv")
boston_housing_df.head()
# Out:
#       CRIM  INDUS    NOX     RM        AGE     DIS  TAX         PT  \
# 0  0.00632   2.31  0.538  6.575  65.199997  4.0900  296  15.300000
# 1  0.02731   7.07  0.469  6.421  78.900002  4.9671  242  17.799999
# 2  0.02729   7.07  0.469  7.185  61.099998  4.9671  242  17.799999
# 3  0.03237   2.18  0.458  6.998  45.799999  6.0622  222  18.700001
# 4  0.06905   2.18  0.458  7.147  54.200001  6.0622  222  18.700001
#
#             B         MV
# 0  396.899994  24.000000
# 1  396.899994  21.600000
# 2  392.829987  34.700001
# 3  394.630005  33.400002
# 4  396.899994  36.200001

# %%
import numpy as np 
boston_housing_df = boston_housing_df[(np.abs(stats.zscore(boston_housing_df))<3).all(axis=1)]

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  463.000000  463.000000  463.000000  463.000000  463.000000  463.000000
# mean     2.358735   10.772981    0.547157    6.297281   67.220950    3.870550
# std      4.720433    6.820539    0.114481    0.644675   28.236259    1.995765
# min      0.006320    0.460000    0.385000    4.368000    2.900000    1.129600
# 25%      0.076890    5.130000    0.448000    5.888500   42.500000    2.197700
# 50%      0.214090    8.560000    0.524000    6.211000   74.300003    3.414500
# 75%      1.921980   18.100000    0.611500    6.618500   93.599998    5.287300
# max     28.655800   27.740000    0.871000    8.375000  100.000000    9.222900
#
#               TAX          PT           B          MV
# count  463.000000  463.000000  463.000000  463.000000
# mean   390.989201   18.336501  374.761855   23.115119
# std    160.054232    2.163748   51.034829    8.811093
# min    188.000000   12.600000   83.449997    5.600000
# 25%    277.000000   16.900000  378.169998   17.799999
# 50%    311.000000   18.700001  392.519989   21.700001
# 75%    437.000000   20.200001  396.899994   25.750000
# max    711.000000   21.200001  396.899994   50.000000

# %%
boston_housing_df['log_CRIM'] = np.log10(boston_housing_df['CRIM'])
boston_housing_df = boston_housing_df.drop(columns = ['CRIM'])
boston_housing_df['log_DIS'] = np.log10(boston_housing_df['DIS'])
boston_housing_df = boston_housing_df.drop(columns = ['DIS'])
boston_housing_df['log_AGE'] = np.log10(boston_housing_df['AGE'])
boston_housing_df = boston_housing_df.drop(columns = ['AGE'])
boston_housing_df['log_NOX'] = np.log10(boston_housing_df['NOX'])
boston_housing_df = boston_housing_df.drop(columns = ['NOX'])

# %%
sns.pairplot(boston_housing_df)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(boston_housing_df.drop("MV", axis=1), boston_housing_df['MV'], test_size = 0.2, random_state = 112)

# %%
import statsmodels.api as sm

# %%
X_train = sm.add_constant(X_train)

# %%
my_model = sm.OLS(Y_train, X_train)

# %%
result=my_model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.665
# Method:                 Least Squares   F-statistic:                     82.55
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           5.29e-82
# Time:                        02:14:13   Log-Likelihood:                -1119.7
# No. Observations:                 370   AIC:                             2259.
# Df Residuals:                     360   BIC:                             2298.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -5.1928      5.653     -0.919      0.359     -16.311       5.925
# INDUS         -0.0863      0.073     -1.182      0.238      -0.230       0.057
# RM             7.9836      0.470     16.994      0.000       7.060       8.907
# TAX           -0.0062      0.003     -2.075      0.039      -0.012      -0.000
# PT            -0.8849      0.146     -6.071      0.000      -1.172      -0.598
# B              0.0144      0.005      2.629      0.009       0.004       0.025
# log_CRIM       0.9721      0.635      1.532      0.126      -0.276       2.220
# log_DIS      -15.5420      2.461     -6.316      0.000     -20.382     -10.702
# log_AGE       -4.7165      1.394     -3.384      0.001      -7.457      -1.976
# log_NOX      -34.3500      7.417     -4.631      0.000     -48.937     -19.763
# ==============================================================================
# Omnibus:                      207.620   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2906.142
# Skew:                           2.037   Prob(JB):                         0.00
# Kurtosis:                      16.112   Cond. No.                     1.60e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
#  Observe the P values in the results for each variable.
#  In previous steps, we found HNR, Jitter(%) to be highly correlated with others. Remove them
#  Also any variable with p-value > 0.05, remove it

# %%
X_train.drop(['INDUS', 'log_CRIM', 'TAX', 'PT', 'B'], axis=1, inplace = True)

# %%
my_model2 = sm.OLS(Y_train, X_train)

# %%
result2 = my_model2.fit()

# %%
print (result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MV   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     144.4
# Date:                Mon, 22 Apr 2019   Prob (F-statistic):           7.37e-74
# Time:                        02:15:59   Log-Likelihood:                -1151.3
# No. Observations:                 370   AIC:                             2313.
# Df Residuals:                     365   BIC:                             2332.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -28.2969      4.461     -6.343      0.000     -37.069     -19.525
# RM             9.0106      0.475     18.965      0.000       8.076       9.945
# log_DIS      -13.0507      2.519     -5.181      0.000     -18.004      -8.098
# log_AGE       -4.9204      1.484     -3.315      0.001      -7.839      -2.002
# log_NOX      -38.2732      6.674     -5.735      0.000     -51.397     -25.149
# ==============================================================================
# Omnibus:                      145.261   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1225.437
# Skew:                           1.414   Prob(JB):                    7.94e-267
# Kurtosis:                      11.455   Cond. No.                         164.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.metrics import r2_score

# %%
X_test = X_test.drop(['INDUS', 'log_CRIM', 'TAX', 'PT', 'B'], axis=1)

# %%
predictions = result2.predict(sm.add_constant(X_test))

# %%
r2_score(Y_test, predictions)
# Out:
# 0.6628365861445957

# %% [markdown]
#  ### STEPS
#  * HEALTH OF DATA - missing values, outliers
#  * DISTRIBUTION OF DATA - should be normal
#  LOOK AT SCATTER PLOTS/CORR OF ALL VARIABLES - shows absence of linear corr..if scatter is curving around
#  it gives hint on what kind of model/transformations to apply
#  Above will give idea of what variables to keep, what transformations to apply
#
#  Lets take Motor Score as dependent variable. Total Score could also be..
#  Others are independent variables/predictors/features

# %% [markdown]
#  ### STEPS
#  * HEALTH OF DATA - Remove any rows with missing values, outliers
#  * DISTRIBUTION OF DATA - ensure data distribution is normal. If not apply transformations/mutations
#  * CHOOSE MODEL - Use OLS if assumptions are met
#  * VERIFY - Validate with test data
#  * ITERATE - Based on results, fine tune the model

# %% [markdown]
#  ### STEPS
#  * ENSURE HEALTH OF DATA - Remove any rows with missing values, outliers
#  * ENSURE DISTRIBUTION OF DATA - ensure data distribution is normal. If not apply transformations/mutations
#  * CHOOSE MODEL - Use OLS if assumptions are met
#  * VERIFY - Validate with test data
#  * ITERATE - Based on results, fine tune the model

# %%
boston_housing_df = pd.read_csv("boston.csv")
boston_housing_df.head()
# Out:
#       CRIM  INDUS    NOX     RM        AGE     DIS  TAX         PT  \
# 0  0.00632   2.31  0.538  6.575  65.199997  4.0900  296  15.300000
# 1  0.02731   7.07  0.469  6.421  78.900002  4.9671  242  17.799999
# 2  0.02729   7.07  0.469  7.185  61.099998  4.9671  242  17.799999
# 3  0.03237   2.18  0.458  6.998  45.799999  6.0622  222  18.700001
# 4  0.06905   2.18  0.458  7.147  54.200001  6.0622  222  18.700001
#
#             B         MV
# 0  396.899994  24.000000
# 1  396.899994  21.600000
# 2  392.829987  34.700001
# 3  394.630005  33.400002
# 4  396.899994  36.200001

# %%
boston_housing_df.dtypes
# Out:
# CRIM     float64
# INDUS    float64
# NOX      float64
# RM       float64
# AGE      float64
# DIS      float64
# TAX        int64
# PT       float64
# B        float64
# MV       float64
# dtype: object

# %% [markdown]
#  Analyze Basic stats to see std-dev, mean etc

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.136779    0.554695    6.284634   68.574901    3.795043
# std      8.601545    6.860353    0.115878    0.702617   28.148862    2.105710
# min      0.006320    0.460000    0.385000    3.561000    2.900000    1.129600
# 25%      0.082045    5.190000    0.449000    5.885500   45.025000    2.100175
# 50%      0.256510    9.690000    0.538000    6.208500   77.500000    3.207450
# 75%      3.677083   18.100000    0.624000    6.623500   94.074999    5.188425
# max     88.976196   27.740000    0.871000    8.780000  100.000000   12.126500
#
#               TAX          PT           B          MV
# count  506.000000  506.000000  506.000000  506.000000
# mean   408.237154   18.455534  356.674030   22.532806
# std    168.537116    2.164946   91.294863    9.197104
# min    187.000000   12.600000    0.320000    5.000000
# 25%    279.000000   17.400000  375.377487   17.025000
# 50%    330.000000   19.050000  391.440002   21.200001
# 75%    666.000000   20.200001  396.225006   25.000000
# max    711.000000   22.000000  396.899994   50.000000

# %%
boston_housing_df.count
# Out:
# <bound method DataFrame.count of          CRIM  INDUS    NOX     RM         AGE     DIS  TAX         PT  \
# 0     0.00632   2.31  0.538  6.575   65.199997  4.0900  296  15.300000
# 1     0.02731   7.07  0.469  6.421   78.900002  4.9671  242  17.799999
# 2     0.02729   7.07  0.469  7.185   61.099998  4.9671  242  17.799999
# 3     0.03237   2.18  0.458  6.998   45.799999  6.0622  222  18.700001
# 4     0.06905   2.18  0.458  7.147   54.200001  6.0622  222  18.700001
# 5     0.02985   2.18  0.458  6.430   58.700001  6.0622  222  18.700001
# 6     0.08829   7.87  0.524  6.012   66.599998  5.5605  311  15.200000
# 7     0.14455   7.87  0.524  6.172   96.099998  5.9505  311  15.200000
# 8     0.21124   7.87  0.524  5.631  100.000000  6.0821  311  15.200000
# 9     0.17004   7.87  0.524  6.004   85.900002  6.5921  311  15.200000
# 10    0.22489   7.87  0.524  6.377   94.300003  6.3467  311  15.200000
# 11    0.11747   7.87  0.524  6.009   82.900002  6.2267  311  15.200000
# 12    0.09378   7.87  0.524  5.889   39.000000  5.4509  311  15.200000
# 13    0.62976   8.14  0.538  5.949   61.799999  4.7075  307  21.000000
# 14    0.63796   8.14  0.538  6.096   84.500000  4.4619  307  21.000000
# 15    0.62739   8.14  0.538  5.834   56.500000  4.4986  307  21.000000
# 16    1.05393   8.14  0.538  5.935   29.299999  4.4986  307  21.000000
# 17    0.78420   8.14  0.538  5.990   81.699997  4.2579  307  21.000000
# 18    0.80271   8.14  0.538  5.456   36.599998  3.7965  307  21.000000
# 19    0.72580   8.14  0.538  5.727   69.500000  3.7965  307  21.000000
# 20    1.25179   8.14  0.538  5.570   98.099998  3.7979  307  21.000000
# 21    0.85204   8.14  0.538  5.965   89.199997  4.0123  307  21.000000
# 22    1.23247   8.14  0.538  6.142   91.699997  3.9769  307  21.000000
# 23    0.98843   8.14  0.538  5.813  100.000000  4.0952  307  21.000000
# 24    0.75026   8.14  0.538  5.924   94.099998  4.3996  307  21.000000
# 25    0.84054   8.14  0.538  5.599   85.699997  4.4546  307  21.000000
# 26    0.67191   8.14  0.538  5.813   90.300003  4.6820  307  21.000000
# 27    0.95577   8.14  0.538  6.047   88.800003  4.4534  307  21.000000
# 28    0.77299   8.14  0.538  6.495   94.400002  4.4547  307  21.000000
# 29    1.00245   8.14  0.538  6.674   87.300003  4.2390  307  21.000000
# ..        ...    ...    ...    ...         ...     ...  ...        ...
# 476   4.87141  18.10  0.614  6.484   93.599998  2.3053  666  20.200001
# 477  15.02340  18.10  0.614  5.304   97.300003  2.1007  666  20.200001
# 478  10.23300  18.10  0.614  6.185   96.699997  2.1705  666  20.200001
# 479  14.33370  18.10  0.614  6.229   88.000000  1.9512  666  20.200001
# 480   5.82401  18.10  0.532  6.242   64.699997  3.4242  666  20.200001
# 481   5.70818  18.10  0.532  6.750   74.900002  3.3317  666  20.200001
# 482   5.73116  18.10  0.532  7.061   77.000000  3.4106  666  20.200001
# 483   2.81838  18.10  0.532  5.762   40.299999  4.0983  666  20.200001
# 484   2.37857  18.10  0.583  5.871   41.900002  3.7240  666  20.200001
# 485   3.67367  18.10  0.583  6.312   51.900002  3.9917  666  20.200001
# 486   5.69175  18.10  0.583  6.114   79.800003  3.5459  666  20.200001
# 487   4.83567  18.10  0.583  5.905   53.200001  3.1523  666  20.200001
# 488   0.15086  27.74  0.609  5.454   92.699997  1.8209  711  20.100000
# 489   0.18337  27.74  0.609  5.414   98.300003  1.7554  711  20.100000
# 490   0.20746  27.74  0.609  5.093   98.000000  1.8226  711  20.100000
# 491   0.10574  27.74  0.609  5.983   98.800003  1.8681  711  20.100000
# 492   0.11132  27.74  0.609  5.983   83.500000  2.1099  711  20.100000
# 493   0.17331   9.69  0.585  5.707   54.000000  2.3817  391  19.200001
# 494   0.27957   9.69  0.585  5.926   42.599998  2.3817  391  19.200001
# 495   0.17899   9.69  0.585  5.670   28.799999  2.7986  391  19.200001
# 496   0.28960   9.69  0.585  5.390   72.900002  2.7986  391  19.200001
# 497   0.26838   9.69  0.585  5.794   70.599998  2.8927  391  19.200001
# 498   0.23912   9.69  0.585  6.019   65.300003  2.4091  391  19.200001
# 499   0.17783   9.69  0.585  5.569   73.500000  2.3999  391  19.200001
# 500   0.22438   9.69  0.585  6.027   79.699997  2.4982  391  19.200001
# 501   0.06263  11.93  0.573  6.593   69.099998  2.4786  273  21.000000
# 502   0.04527  11.93  0.573  6.120   76.699997  2.2875  273  21.000000
# 503   0.06076  11.93  0.573  6.976   91.000000  2.1675  273  21.000000
# 504   0.10959  11.93  0.573  6.794   89.300003  2.3889  273  21.000000
# 505   0.04741  11.93  0.573  6.030   80.800003  2.5050  273  21.000000
#
#               B         MV
# 0    396.899994  24.000000
# 1    396.899994  21.600000
# 2    392.829987  34.700001
# 3    394.630005  33.400002
# 4    396.899994  36.200001
# 5    394.119995  28.700001
# 6    395.600006  22.900000
# 7    396.899994  27.100000
# 8    386.630005  16.500000
# 9    386.709992  18.900000
# 10   392.519989  15.000000
# 11   396.899994  18.900000
# 12   390.500000  21.700001
# 13   396.899994  20.400000
# 14   380.019989  18.200001
# 15   395.619995  19.900000
# 16   386.850006  23.100000
# 17   386.750000  17.500000
# 18   288.989990  20.200001
# 19   390.950012  18.200001
# 20   376.570007  13.600000
# 21   392.529999  19.600000
# 22   396.899994  15.200000
# 23   394.540008  14.500000
# 24   394.329987  15.600000
# 25   303.420013  13.900000
# 26   376.880005  16.600000
# 27   306.380005  14.800000
# 28   387.940002  18.400000
# 29   380.230011  21.000000
# ..          ...        ...
# 476  396.209992  16.700001
# 477  349.480011  12.000000
# 478  379.700012  14.600000
# 479  383.320007  21.400000
# 480  396.899994  23.000000
# 481  393.070007  23.700001
# 482  395.279999  25.000000
# 483  392.920013  21.799999
# 484  370.730011  20.600000
# 485  388.619995  21.200001
# 486  392.679993  19.100000
# 487  388.220001  20.600000
# 488  395.089996  15.200000
# 489  344.049988   7.000000
# 490  318.429993   8.100000
# 491  390.109985  13.600000
# 492  396.899994  20.100000
# 493  396.899994  21.799999
# 494  396.899994  24.500000
# 495  393.290008  23.100000
# 496  396.899994  19.700001
# 497  396.899994  18.299999
# 498  396.899994  21.200001
# 499  395.769989  17.500000
# 500  396.899994  16.799999
# 501  391.989990  22.400000
# 502  396.899994  20.600000
# 503  396.899994  23.900000
# 504  393.450012  22.000000
# 505  396.899994  11.900000
#
# [506 rows x 10 columns]>

# %%
boston_housing_df.shape
# Out:
# (506, 10)

# %%
import numpy as np 
boston_housing_df = boston_housing_df[(np.abs(stats.zscore(boston_housing_df))<3).all(axis=1)]

# %%
pd.DataFrame.describe(boston_housing_df)
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  463.000000  463.000000  463.000000  463.000000  463.000000  463.000000
# mean     2.358735   10.772981    0.547157    6.297281   67.220950    3.870550
# std      4.720433    6.820539    0.114481    0.644675   28.236259    1.995765
# min      0.006320    0.460000    0.385000    4.368000    2.900000    1.129600
# 25%      0.076890    5.130000    0.448000    5.888500   42.500000    2.197700
# 50%      0.214090    8.560000    0.524000    6.211000   74.300003    3.414500
# 75%      1.921980   18.100000    0.611500    6.618500   93.599998    5.287300
# max     28.655800   27.740000    0.871000    8.375000  100.000000    9.222900
#
#               TAX          PT           B          MV
# count  463.000000  463.000000  463.000000  463.000000
# mean   390.989201   18.336501  374.761855   23.115119
# std    160.054232    2.163748   51.034829    8.811093
# min    188.000000   12.600000   83.449997    5.600000
# 25%    277.000000   16.900000  378.169998   17.799999
# 50%    311.000000   18.700001  392.519989   21.700001
# 75%    437.000000   20.200001  396.899994   25.750000
# max    711.000000   21.200001  396.899994   50.000000

# %%
boston_housing_df.shape
# Out:
# (463, 10)

# %% [markdown]
#  Around 40 rows out of 506 were removed (~10%) - thats acceptable
